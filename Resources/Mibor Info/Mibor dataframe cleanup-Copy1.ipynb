# %%
import pandas as pd

boone20a= pd.read_csv("Listing-boone-06-01-2020-12-31-2020.csv")
# _df= pd.read_csv("Listing-boone-06-01-2019-12-31-2019.csv")
# _df= pd.read_csv("Listing-hamilton-06-01-2019-12-31-2019.csv")
# _df= pd.read_csv("Listing-hamilton-06-01-2020-07-31-2020.csv")
# _df= pd.read_csv("Listing-hamilton-08-01-2020-12-31-2020.csv")
# _df= pd.read_csv("Listing-hancock-06-01-2019-12-31-2019.csv")
# _df= pd.read_csv("Listing-hancock-06-01-2020-12-31-2020.csv")
# _df= pd.read_csv("Listing-hendricks-06-01-2019-12-31-2019.csv")
# _df= pd.read_csv("Listing-hendricks-06-01-2020-12-31-2020.csv")
johnson19_a= pd.read_csv("Listing-johnson-06-01-2019-12-31-2019.csv")
johnson20_a= pd.read_csv("Listing-johnson-06-01-2020-12-31-2020.csv")
marion19_a= pd.read_csv("Listing-marion-06-01-2019-08-31-2019.csv")
marion20_a= pd.read_csv("Listing-marion-06-01-2020-08-31-2020.csv")
marion19_b = pd.read_csv("Listing-marion-09-01-2019-11-30-2019.csv")
marion20_b= pd.read_csv("Listing-marion-09-01-2020-11-30-2020.csv")
marion19_c= pd.read_csv("Listing-marion-11-01-2019-12-31-2019.csv")
marion20_c= pd.read_csv("Listing-marion-11-01-2020-12-31-2020.csv")
# _df= pd.read_csv("single-line-boone-06-01-2019-12-31-2019.csv")
boone20b= pd.read_csv("single-line-boone-06-01-2020-12-31-2020.csv")
# _df= pd.read_csv("single-line-hamilton- 06-01-2020-07-31-2020.csv")
# _df= pd.read_csv("single-line-hamilton-06-01-2019-12-31-2019.csv")
# _df= pd.read_csv("single-line-hamilton-08-01-2020-12-31-2020.csv")
# _df= pd.read_csv("single-line-hancock-06-01-2019-12-31-2019.csv")
# _df= pd.read_csv("single-line-hancock-06-01-2020-12-31-2020.csv")
# _df= pd.read_csv("single-line-hendricks-06-01-2019-12-31-2019.csv")
# _df= pd.read_csv("single-line-hendricks-06-01-2020-12-31-2020.csv")
johnson19a= pd.read_csv("single-line-johnson-06-01-2019-12-31-2019.csv")
johnson20a= pd.read_csv("single-line-johnson-06-01-2020-12-31-2020.csv")
marion19a= pd.read_csv("single-line-marion-06-01-2019-08-31-2019.csv")
marion20a= pd.read_csv("single-line-marion-06-01-2020-08-31-2020.csv")
marion19b= pd.read_csv("single-line-marion-09-01-2019-11-30-2019.csv")
marion20b= pd.read_csv("single-line-marion-09-01-2020-11-30-2020.csv")
marion19c= pd.read_csv("single-line-marion-11-01-2019-12-31-2019.csv")
marion20c= pd.read_csv("single-line-marion-11-01-2020-12-31-2020.csv")

# %%
new_df = pd.merge(boone20a, boone20b, left_on = 'MLSNumber', right_on = 'BLC # ')

new_df
# Out:
#       MLSNumber  NewConstructionYN PropertyType PropertySubType  \
# 0      21757458                NaN  Residential      Single Fam
# 1      21755918                NaN  Residential      Single Fam
# 2      21752886                NaN  Residential      Single Fam
# 3      21754272                NaN  Residential      Single Fam
# 4      21757135                NaN  Residential      Single Fam
# ...         ...                ...          ...             ...
# 1054   21740416                NaN  Residential      Single Fam
# 1055   21731362                NaN  Residential      Single Fam
# 1056   21728765                NaN  Residential      Single Fam
# 1057   21726200                NaN  Residential      Single Fam
# 1058   21728305                NaN  Residential      Single Fam
#
#       StreetNumberAlpha          StreetName  ListAgentFullName  \
# 0                   NaN                 700     Robbin Edwards
# 1                   NaN  Whitestown Parkway         Stan Comer
# 2                   NaN              Farlin      Marie Edwards
# 3                   NaN              Farlin      Marie Edwards
# 4                   NaN               Peggy        Vern Carter
# ...                 ...                 ...                ...
# 1054                NaN                 225  Rodney Richardson
# 1055                NaN                 500       Ryan Radecki
# 1056                NaN                 275        Heidi Wolff
# 1057                NaN                 150       Lisa K Batts
# 1058                NaN                 450       Deena Cooper
#
#      CoListAgentFullName  OriginalListPrice  ListPrice  ...       Subdivision  \
# 0                    NaN           215000.0     195000  ...    NO SUBDIVISION
# 1                    NaN           300000.0     300000  ...    NO SUBDIVISION
# 2                    NaN           391623.0     391624  ...  WESTWOOD LANDING
# 3                    NaN           406033.0     406033  ...  WESTWOOD LANDING
# 4                    NaN           424900.0     424900  ...         HAMPSHIRE
# ...                  ...                ...        ...  ...               ...
# 1054                 NaN           324998.0     324998  ...    NO SUBDIVISION
# 1055         Angela Line           410000.0     395900  ...    NO SUBDIVISION
# 1056                 NaN           625000.0     650000  ...    NO SUBDIVISION
# 1057                 NaN           595000.0     595000  ...    NO SUBDIVISION
# 1058                 NaN           585000.0     585000  ...    NO SUBDIVISION
#
#      # Fireplaces   Lvls                   Gar  # of Garage Spaces  \
# 0               1  1LEVL                ATTACH                   2
# 1               0  1LEVL         DETATCH,MULTI                  4+
# 2               1  1LEVL                ATTACH                   3
# 3               1  2LEVL                ATTACH                   3
# 4               1  2LEVL                ATTACH                   3
# ...           ...    ...                   ...                 ...
# 1054            1  1LEVL                ATTACH                   3
# 1055            1  2LEVL          ATTACH,MULTI                   2
# 1056            1  2LEVL  ATTACH,DETATCH,MULTI                  4+
# 1057            1  2LEVL                ATTACH                   3
# 1058            0  1LEVL                ATTACH                   3
#
#       Sq Ft Main Upper Basement Total Sq Ft DOM  List Office MLSID
# 0                1,582       No       1,582  40             ECOR01
# 1                1,112      Yes       1,390  52             CARP12
# 2                2,893       No       2,893  69             HMSR01
# 3                3,138       No       3,138  67             HMSR01
# 4                3,115       No       3,115  44             FFRL01
# ...                ...      ...         ...  ..                ...
# 1054             1,618       No       1,618   4             RIRC01
# 1055             2,800       No       2,800  31             EZST01
# 1056             5,070       No       5,070  48             REAB08
# 1057             2,508      Yes       3,684   8             BREG01
# 1058             2,212      Yes       3,535   2             CARP26
#
# [1059 rows x 35 columns]

# %%
boone20a['MLSNumber'].nunique()
# Out:
# 1059

# %%
boone20b = boone20b.rename(columns = {'MLSNumber': 'BLC # '}, inplace = False)

boone20b
# Out:
#       Unnamed: 0    BLC #       St P Type                    Address  Area  \
# 0              1  21757458  Active    SFD               5486 S 700 E   601
# 1              1  21755918  Active    SFD  7370 E Whitestown Parkway   601
# 2              1  21752886  Active    SFD             6156 Farlin Dr   601
# 3              1  21754272  Active    SFD             6088 Farlin Dr   601
# 4              1  21757135  Active    SFD              8177 Peggy Ct   601
# ...          ...       ...     ...    ...                        ...   ...
# 1054        1001  21740416       S    SFD               7505 N 225 W   612
# 1055        1001  21731362       S    SFD                731 W 500 N   612
# 1056        1001  21728765       S    SFD               4855 N 275 W   612
# 1057        1001  21726200       S    SFD               4861 N 150 W   612
# 1058        1001  21728305       S    SFD               5110 W 450 N   612
#
#      List/MoRnt $  Beds Total  Baths Full  Baths Half  ...       Subdivision  \
# 0        $195,000           3           1           0  ...    NO SUBDIVISION
# 1        $300,000           2           2           0  ...    NO SUBDIVISION
# 2        $391,624           3           2           1  ...  WESTWOOD LANDING
# 3        $406,033           4           3           1  ...  WESTWOOD LANDING
# 4        $424,900           4           2           1  ...         HAMPSHIRE
# ...           ...         ...         ...         ...  ...               ...
# 1054     $325,000           3           2           0  ...    NO SUBDIVISION
# 1055     $393,000           3           2           1  ...    NO SUBDIVISION
# 1056     $575,000           3           3           0  ...    NO SUBDIVISION
# 1057     $575,000           3           2           1  ...    NO SUBDIVISION
# 1058     $585,000           4           3           1  ...    NO SUBDIVISION
#
#      # Fireplaces   Lvls                   Gar # of Garage Spaces  \
# 0               1  1LEVL                ATTACH                  2
# 1               0  1LEVL         DETATCH,MULTI                 4+
# 2               1  1LEVL                ATTACH                  3
# 3               1  2LEVL                ATTACH                  3
# 4               1  2LEVL                ATTACH                  3
# ...           ...    ...                   ...                ...
# 1054            1  1LEVL                ATTACH                  3
# 1055            1  2LEVL          ATTACH,MULTI                  2
# 1056            1  2LEVL  ATTACH,DETATCH,MULTI                 4+
# 1057            1  2LEVL                ATTACH                  3
# 1058            0  1LEVL                ATTACH                  3
#
#      Sq Ft Main Upper Basement Total Sq Ft DOM  List Office MLSID
# 0               1,582       No       1,582  40             ECOR01
# 1               1,112      Yes       1,390  52             CARP12
# 2               2,893       No       2,893  69             HMSR01
# 3               3,138       No       3,138  67             HMSR01
# 4               3,115       No       3,115  44             FFRL01
# ...               ...      ...         ...  ..                ...
# 1054            1,618       No       1,618   4             RIRC01
# 1055            2,800       No       2,800  31             EZST01
# 1056            5,070       No       5,070  48             REAB08
# 1057            2,508      Yes       3,684   8             BREG01
# 1058            2,212      Yes       3,535   2             CARP26
#
# [1059 rows x 21 columns]

# %%
new_df
# Out:
#       MLSNumber  NewConstructionYN PropertyType PropertySubType  \
# 0      21757458                NaN  Residential      Single Fam
# 1      21755918                NaN  Residential      Single Fam
# 2      21752886                NaN  Residential      Single Fam
# 3      21754272                NaN  Residential      Single Fam
# 4      21757135                NaN  Residential      Single Fam
# ...         ...                ...          ...             ...
# 1054   21740416                NaN  Residential      Single Fam
# 1055   21731362                NaN  Residential      Single Fam
# 1056   21728765                NaN  Residential      Single Fam
# 1057   21726200                NaN  Residential      Single Fam
# 1058   21728305                NaN  Residential      Single Fam
#
#       StreetNumberAlpha          StreetName  ListAgentFullName  \
# 0                   NaN                 700     Robbin Edwards
# 1                   NaN  Whitestown Parkway         Stan Comer
# 2                   NaN              Farlin      Marie Edwards
# 3                   NaN              Farlin      Marie Edwards
# 4                   NaN               Peggy        Vern Carter
# ...                 ...                 ...                ...
# 1054                NaN                 225  Rodney Richardson
# 1055                NaN                 500       Ryan Radecki
# 1056                NaN                 275        Heidi Wolff
# 1057                NaN                 150       Lisa K Batts
# 1058                NaN                 450       Deena Cooper
#
#      CoListAgentFullName  OriginalListPrice  ListPrice  ...       Subdivision  \
# 0                    NaN           215000.0     195000  ...    NO SUBDIVISION
# 1                    NaN           300000.0     300000  ...    NO SUBDIVISION
# 2                    NaN           391623.0     391624  ...  WESTWOOD LANDING
# 3                    NaN           406033.0     406033  ...  WESTWOOD LANDING
# 4                    NaN           424900.0     424900  ...         HAMPSHIRE
# ...                  ...                ...        ...  ...               ...
# 1054                 NaN           324998.0     324998  ...    NO SUBDIVISION
# 1055         Angela Line           410000.0     395900  ...    NO SUBDIVISION
# 1056                 NaN           625000.0     650000  ...    NO SUBDIVISION
# 1057                 NaN           595000.0     595000  ...    NO SUBDIVISION
# 1058                 NaN           585000.0     585000  ...    NO SUBDIVISION
#
#      # Fireplaces   Lvls                   Gar  # of Garage Spaces  \
# 0               1  1LEVL                ATTACH                   2
# 1               0  1LEVL         DETATCH,MULTI                  4+
# 2               1  1LEVL                ATTACH                   3
# 3               1  2LEVL                ATTACH                   3
# 4               1  2LEVL                ATTACH                   3
# ...           ...    ...                   ...                 ...
# 1054            1  1LEVL                ATTACH                   3
# 1055            1  2LEVL          ATTACH,MULTI                   2
# 1056            1  2LEVL  ATTACH,DETATCH,MULTI                  4+
# 1057            1  2LEVL                ATTACH                   3
# 1058            0  1LEVL                ATTACH                   3
#
#       Sq Ft Main Upper Basement Total Sq Ft DOM  List Office MLSID
# 0                1,582       No       1,582  40             ECOR01
# 1                1,112      Yes       1,390  52             CARP12
# 2                2,893       No       2,893  69             HMSR01
# 3                3,138       No       3,138  67             HMSR01
# 4                3,115       No       3,115  44             FFRL01
# ...                ...      ...         ...  ..                ...
# 1054             1,618       No       1,618   4             RIRC01
# 1055             2,800       No       2,800  31             EZST01
# 1056             5,070       No       5,070  48             REAB08
# 1057             2,508      Yes       3,684   8             BREG01
# 1058             2,212      Yes       3,535   2             CARP26
#
# [1059 rows x 35 columns]

# %%
marion20_single_line = pd.concat([marion20a, marion20b, marion20c])

marion20_single_line
# Out:
#       Unnamed: 0    BLC #       St P Type                        Address  \
# 0              1  21732062  Active    CND  6454 Potomac Square Ln Unit#7
# 1              1  21734409  Active    SFD           7545 SEDGE MEADOW Dr
# 2              1  21730974  Active    SFD                  7014 Andre Dr
# 3              1  21715582  Active    CND     4000 N Meridian St Unit#2A
# 4              1  21729240  Active    SFD                  534 E 40TH St
# ...          ...       ...     ...    ...                            ...
# 3717        3501  21730417       S    SFD               2426 Shaw Avenue
# 3718        3501  21737135       S    SFD                 1646 Desoto Ln
# 3719        3501  21752168       S    SFD               2527 Philwood Dr
# 3720        3501  21734884       S    SFD                 1120 Rosner Dr
# 3721        3501  21745998       S    SFD                 5035 W 14TH St
#
#       Area List/MoRnt $  Beds Total  Baths Full  Baths Half  ...  \
# 0     4902     $130,000           2           2           1  ...
# 1     4902     $839,900           5           4           2  ...
# 2     4902     $895,000           5           5           1  ...
# 3     4903     $159,000           1           1           0  ...
# 4     4903     $164,999           2           1           0  ...
# ...    ...          ...         ...         ...         ...  ...
# 3717  4993     $201,000           3           1           2  ...
# 3718  4993     $204,500           3           1           1  ...
# 3719  4993     $210,000           3           2           1  ...
# 3720  4993     $214,900           2           2           0  ...
# 3721  4993     $230,000           3           2           0  ...
#
#                       Subdivision # Fireplaces   Lvls           Gar  \
# 0                      GEORGETOWN            1  2LEVL        ATTACH
# 1     THE PRESERVE AT EAGLE CREEK            2  1HALF  ATTACH,MULTI
# 2                  NORMANDY FARMS            2  2LEVL        ATTACH
# 3                TARKINGTON TOWER            0  1LEVL        ATTACH
# 4                NORTHERN HEIGHTS            1  1LEVL          NONE
# ...                           ...          ...    ...           ...
# 3717               SPEEDWAY MANOR            0  1LEVL        ATTACH
# 3718     SPEEDWAY CUNNINGHAM PARK            1  1LEVL        ATTACH
# 3719          FALENDERS MEADOWOOD            0  1LEVL        ATTACH
# 3720               NO SUBDIVISION            1  1LEVL       DETATCH
# 3721                SPEEDWAY CITY            1  1LEVL       DETATCH
#
#      # of Garage Spaces Sq Ft Main Upper Basement Total Sq Ft  DOM  \
# 0                     2            1,600       No       1,600   11
# 1                    4+            4,823      Yes       8,646  150
# 2                     3            3,256      Yes       5,203  163
# 3                     1            1,000       No       1,000  235
# 4                   NaN            1,261      Yes       2,445  171
# ...                 ...              ...      ...         ...  ...
# 3717                  2            1,053      Yes       2,106   57
# 3718                  2            1,232      Yes       2,464   24
# 3719                  2            1,160      Yes       2,320    2
# 3720                 4+            1,232      Yes       1,722   35
# 3721                  2            1,092      Yes       2,184    3
#
#       List Office MLSID
# 0                SVTN01
# 1                WSRL01
# 2                BHHS01
# 3                EXPL01
# 4                CBRL01
# ...                 ...
# 3717             BHHS01
# 3718             FTRE01
# 3719             TUCK04
# 3720             NRET01
# 3721             KWIN01
#
# [13591 rows x 21 columns]

# %%
marion19_single_line = pd.concat([marion19a, marion19b, marion19c])

marion19_single_line
# Out:
#       Unnamed: 0    BLC #       St P Type             Address  Area  \
# 0              1  21646528  Active    SFD  7575 N Illinois St  4903
# 1              1  21651933  Active    SFD      6639 E 52nd St  4904
# 2              1  21664090  Active    SFD   2221 N Leland Ave  4905
# 3              1  21651300  Active    SFD    7309 Parklake Pl  4907
# 4              1  21664092  Active    SFD    1112 W Eugene St  4911
# ...          ...       ...     ...    ...                 ...   ...
# 2306        2001  21660279       S    SFD      5808 W 18th St  4993
# 2307        2001  21667492       S    SFD    2055 Gerrard Ave  4993
# 2308        2001  21670216       S    SFD        5868 Nash Ln  4993
# 2309        2001  21664810       S    SFD     6035 N Maren Dr  4993
# 2310        2001  21670629       S    SFD   5844 Hollister Dr  4993
#
#      List/MoRnt $  Beds Total  Baths Full  Baths Half  ...  \
# 0        $799,900           5           4           1  ...
# 1        $489,000           3           1           0  ...
# 2         $65,000           2           1           0  ...
# 3        $489,000           3           2           0  ...
# 4         $90,000           3           1           1  ...
# ...           ...         ...         ...         ...  ...
# 2306     $174,900           3           1           1  ...
# 2307     $185,000           2           2           0  ...
# 2308     $188,000           4           2           0  ...
# 2309     $199,900           4           2           0  ...
# 2310     $204,900           4           1           1  ...
#
#                    Subdivision # Fireplaces   Lvls      Gar  \
# 0         NORTH MERIDIAN HILLS            2  1HALF   ATTACH
# 1                   BROOKHAVEN            1  1LEVL  DETATCH
# 2              EMERSON GARDENS            0  1LEVL  DETATCH
# 3      PARK VIEW AT WELLINGTON            0  1LEVL   ATTACH
# 4                      BRADENS            0  1HALF  DETATCH
# ...                        ...          ...    ...      ...
# 2306        SCHLOSS HOME PLACE            1  1LEVL  DETATCH
# 2307       EVERETT M SCHOFIELD            4  2LEVL  DETATCH
# 2308  SPEEDWAY CUNNINGHAM PARK            0  1LEVL  DETATCH
# 2309       FALENDERS MEADOWOOD            0  2LEVL   ATTACH
# 2310       FALENDERS MEADOWOOD            1  TRILV  DETATCH
#
#      # of Garage Spaces Sq Ft Main Upper Basement Total Sq Ft  DOM  \
# 0                     2            3,412      Yes       5,716  484
# 1                     1              936       No         936  356
# 2                     2              840       No         840  515
# 3                     2            1,240       No       1,240  356
# 4                     1            1,884      Yes       1,884  514
# ...                 ...              ...      ...         ...  ...
# 2306                  2            1,456      Yes       2,512   35
# 2307                  1              831      Yes       1,629    6
# 2308                  1            1,040      Yes       2,080   21
# 2309                  2            1,954      Yes       2,916   45
# 2310                  2            1,768      Yes       2,248    2
#
#       List Office MLSID
# 0                MCNU01
# 1                CORP01
# 2                NOLI01
# 3                CORP01
# 4                NOLI01
# ...                 ...
# 2306             TRBL01
# 2307             REAR01
# 2308             KWIN04
# 2309             BHHS03
# 2310             CARP04
#
# [10541 rows x 21 columns]

# %%
marion19_listing = pd.concat([marion19_a, marion19_b, marion19_c])

marion19_listing
# Out:
#       MLSNumber  NewConstructionYN PropertyType PropertySubType  \
# 0      21646528                NaN  Residential      Single Fam
# 1      21651933                NaN  Residential      Single Fam
# 2      21664090                NaN  Residential      Single Fam
# 3      21651300                NaN  Residential      Single Fam
# 4      21664092                NaN  Residential      Single Fam
# ...         ...                ...          ...             ...
# 2306   21660279                NaN  Residential      Single Fam
# 2307   21667492                NaN  Residential      Single Fam
# 2308   21670216                NaN  Residential      Single Fam
# 2309   21664810                NaN  Residential      Single Fam
# 2310   21670629                NaN  Residential      Single Fam
#
#       StreetNumberAlpha StreetName     ListAgentFullName CoListAgentFullName  \
# 0                   NaN   Illinois           Tom McNulty                 NaN
# 1                   NaN       52nd         Keith Dedrick                 NaN
# 2                   NaN     Leland        Charlene Gaard                 NaN
# 3                   NaN   Parklake         Keith Dedrick                 NaN
# 4                   NaN     Eugene        Charlene Gaard                 NaN
# ...                 ...        ...                   ...                 ...
# 2306                NaN       18th           Brian Black                 NaN
# 2307                NaN    Gerrard        Eric Cottongim                 NaN
# 2308                NaN       Nash  Christopher G. Price                 NaN
# 2309                NaN      Maren         Dean A. Hicks                 NaN
# 2310                NaN  Hollister        Sibylle Walker                 NaN
#
#       OriginalListPrice  ListPrice ListingContractDate ExpirationDate  \
# 0              974900.0     799900          2019-06-22            NaN
# 1             3300000.0     489000          2019-07-02            NaN
# 2               65000.0      65000          2019-08-28            NaN
# 3             3300000.0     489000          2019-06-28            NaN
# 4               90000.0      90000          2019-08-29            NaN
# ...                 ...        ...                 ...            ...
# 2306           189900.0     174900          2019-08-06     2019-12-06
# 2307              200.0     200000          2019-09-13     2019-12-13
# 2308           200000.0     190000          2019-09-20     2020-03-24
# 2309           219900.0     199900          2019-08-27     2020-03-26
# 2310           204900.0     204900          2019-09-23     2020-03-23
#
#            SellingOfficeName SellingAgentFullName
# 0                        NaN                   NaN
# 1                        NaN                   NaN
# 2                        NaN                   NaN
# 3                        NaN                   NaN
# 4                        NaN                   NaN
# ...                      ...                   ...
# 2306    Carpenter, REALTORS®    Jennifer L. Turner
# 2307      RE/MAX Centerstone         Robin Pickett
# 2308  RE/MAX Advanced Realty          Karen Newman
# 2309      CENTURY 21 Scheetz       Barbara J. Bade
# 2310     F.C. Tucker Company       David T. Jessee
#
# [10541 rows x 14 columns]

# %%
marion20_listing = pd.concat([marion20_a, marion20_b, marion20_c])

marion20_listing
# Out:
#       MLSNumber  NewConstructionYN PropertyType PropertySubType  \
# 0      21732062                NaN  Residential           Condo
# 1      21734409                NaN  Residential      Single Fam
# 2      21730974                NaN  Residential      Single Fam
# 3      21715582                NaN  Residential           Condo
# 4      21729240                NaN  Residential      Single Fam
# ...         ...                ...          ...             ...
# 3717   21730417                NaN  Residential      Single Fam
# 3718   21737135                NaN  Residential      Single Fam
# 3719   21752168                NaN  Residential      Single Fam
# 3720   21734884                NaN  Residential      Single Fam
# 3721   21745998                NaN  Residential      Single Fam
#
#       StreetNumberAlpha      StreetName            ListAgentFullName  \
# 0                   NaN  Potomac Square            LaTasha Stevenson
# 1                   NaN    SEDGE MEADOW  Joshua Baradaran-Dilmaghani
# 2                   NaN           Andre                  James Stone
# 3                   NaN        Meridian                 Rodney Heard
# 4                   NaN            40TH                   Dave Ellis
# ...                 ...             ...                          ...
# 3717                NaN     Shaw Avenue             Timothy O'Connor
# 3718                NaN          Desoto                 Devin Hunter
# 3719                NaN        Philwood                  Karen Welch
# 3720                NaN          Rosner                Nancy Dewbrew
# 3721                NaN            14TH                 Jordan Moody
#
#      CoListAgentFullName  OriginalListPrice  ListPrice ListingContractDate  \
# 0                    NaN           130000.0     130000          2020-08-14
# 1                    NaN           869900.0     839900          2020-08-27
# 2                    NaN           895000.0     895000          2020-08-14
# 3           Jason Miller           174900.0     159000          2020-06-02
# 4                    NaN           190000.0     164999          2020-07-31
# ...                  ...                ...        ...                 ...
# 3717       Bill McMurray           225000.0     209000          2020-08-06
# 3718                 NaN           199550.0     204500          2020-09-05
# 3719                 NaN           209000.0     209000          2020-11-16
# 3720                 NaN           214900.0     214900          2020-08-25
# 3721                 NaN           225000.0     225000          2020-10-15
#
#      ExpirationDate               SellingOfficeName SellingAgentFullName
# 0               NaN                             NaN                   NaN
# 1               NaN                             NaN                   NaN
# 2               NaN                             NaN                   NaN
# 3               NaN                             NaN                   NaN
# 4               NaN                             NaN                   NaN
# ...             ...                             ...                   ...
# 3717     2021-02-05          The Stewart Home Group   Abigail Fitzpatrick
# 3718     2021-03-05          Realty One Group Dream      Melissa Reynolds
# 3719     2021-05-16            Carpenter, REALTORS®        Donna Robinson
# 3720     2021-02-24  Central Indiana Real Estate LL      Nancy A. Dewbrew
# 3721     2021-04-15              CENTURY 21 Scheetz           Sandra Ginn
#
# [13591 rows x 14 columns]

# %%
marion_19 = pd.merge(marion19_listing, marion19_single_line, left_on = 'MLSNumber', right_on = 'BLC # ')

marion_19
# Out:
#        MLSNumber  NewConstructionYN PropertyType PropertySubType  \
# 0       21646528                NaN  Residential      Single Fam
# 1       21651933                NaN  Residential      Single Fam
# 2       21664090                NaN  Residential      Single Fam
# 3       21651300                NaN  Residential      Single Fam
# 4       21664092                NaN  Residential      Single Fam
# ...          ...                ...          ...             ...
# 12784   21679870                NaN  Residential      Single Fam
# 12785   21680832                NaN  Residential      Single Fam
# 12786   21681131                NaN  Residential      Single Fam
# 12787   21678923                NaN  Residential      Single Fam
# 12788   21670216                NaN  Residential      Single Fam
#
#        StreetNumberAlpha   StreetName     ListAgentFullName  \
# 0                    NaN     Illinois           Tom McNulty
# 1                    NaN         52nd         Keith Dedrick
# 2                    NaN       Leland        Charlene Gaard
# 3                    NaN     Parklake         Keith Dedrick
# 4                    NaN       Eugene        Charlene Gaard
# ...                  ...          ...                   ...
# 12784                NaN  FOREST RISE          Robyn Breece
# 12785                NaN       Auburn          David Morris
# 12786                NaN       Presto         Shelly Wilson
# 12787                NaN   Cunningham           Karen Welch
# 12788                NaN         Nash  Christopher G. Price
#
#       CoListAgentFullName  OriginalListPrice  ListPrice  ...  \
# 0                     NaN           974900.0     799900  ...
# 1                     NaN          3300000.0     489000  ...
# 2                     NaN            65000.0      65000  ...
# 3                     NaN          3300000.0     489000  ...
# 4                     NaN            90000.0      90000  ...
# ...                   ...                ...        ...  ...
# 12784                 NaN           164990.0     164990  ...
# 12785                 NaN            95000.0      95000  ...
# 12786                 NaN           129900.0     129900  ...
# 12787                 NaN           148500.0     148500  ...
# 12788                 NaN           200000.0     190000  ...
#
#                     Subdivision # Fireplaces   Lvls      Gar  \
# 0          NORTH MERIDIAN HILLS            2  1HALF   ATTACH
# 1                    BROOKHAVEN            1  1LEVL  DETATCH
# 2               EMERSON GARDENS            0  1LEVL  DETATCH
# 3       PARK VIEW AT WELLINGTON            0  1LEVL   ATTACH
# 4                       BRADENS            0  1HALF  DETATCH
# ...                         ...          ...    ...      ...
# 12784  THE WOODS AT BEECH GROVE            0  2LEVL   ATTACH
# 12785       EVERETT M SCHOFIELD            0  1LEVL  DETATCH
# 12786        SCHLOSS HOME PLACE            0  1LEVL  DETATCH
# 12787       BAKERS WALNUT GROVE            0  1LEVL  DETATCH
# 12788  SPEEDWAY CUNNINGHAM PARK            0  1LEVL  DETATCH
#
#        # of Garage Spaces  Sq Ft Main Upper Basement Total Sq Ft  DOM  \
# 0                       2             3,412      Yes       5,716  484
# 1                       1               936       No         936  356
# 2                       2               840       No         840  515
# 3                       2             1,240       No       1,240  356
# 4                       1             1,884      Yes       1,884  514
# ...                   ...               ...      ...         ...  ...
# 12784                   2             1,592       No       1,592    5
# 12785                   1               660      Yes       1,320    1
# 12786                   2               864      Yes       1,728    3
# 12787                   1             1,060      Yes       2,120    2
# 12788                   1             1,040      Yes       2,080   21
#
#        List Office MLSID
# 0                 MCNU01
# 1                 CORP01
# 2                 NOLI01
# 3                 CORP01
# 4                 NOLI01
# ...                  ...
# 12784             EZST01
# 12785             EXPL01
# 12786             REAR03
# 12787             TUCK04
# 12788             KWIN04
#
# [12789 rows x 35 columns]

# %%
marion_20 = pd.merge(marion20_listing, marion20_single_line, left_on = 'MLSNumber', right_on = 'BLC # ')

marion_20
# Out:
#        MLSNumber  NewConstructionYN PropertyType PropertySubType  \
# 0       21732062                NaN  Residential           Condo
# 1       21734409                NaN  Residential      Single Fam
# 2       21730974                NaN  Residential      Single Fam
# 3       21715582                NaN  Residential           Condo
# 4       21729240                NaN  Residential      Single Fam
# ...          ...                ...          ...             ...
# 16894   21745947                NaN  Residential      Single Fam
# 16895   21750995                NaN  Residential      Single Fam
# 16896   21749435                NaN  Residential      Single Fam
# 16897   21749028                NaN  Residential      Single Fam
# 16898   21752168                NaN  Residential      Single Fam
#
#        StreetNumberAlpha      StreetName            ListAgentFullName  \
# 0                    NaN  Potomac Square            LaTasha Stevenson
# 1                    NaN    SEDGE MEADOW  Joshua Baradaran-Dilmaghani
# 2                    NaN           Andre                  James Stone
# 3                    NaN        Meridian                 Rodney Heard
# 4                    NaN            40TH                   Dave Ellis
# ...                  ...             ...                          ...
# 16894                NaN        Lynhurst               Donna Robinson
# 16895                NaN            Ford                  Daniel Nohe
# 16896                NaN           MAREN                 Geneva Tyler
# 16897                NaN       MACARTHUR                  Sandra Ginn
# 16898                NaN        Philwood                  Karen Welch
#
#       CoListAgentFullName  OriginalListPrice  ListPrice  ...  \
# 0                     NaN           130000.0     130000  ...
# 1                     NaN           869900.0     839900  ...
# 2                     NaN           895000.0     895000  ...
# 3            Jason Miller           174900.0     159000  ...
# 4                     NaN           190000.0     164999  ...
# ...                   ...                ...        ...  ...
# 16894                 NaN           167000.0     159900  ...
# 16895           Tina Nohe           160000.0     160000  ...
# 16896                 NaN           185000.0     173900  ...
# 16897                 NaN           169900.0     169900  ...
# 16898                 NaN           209000.0     209000  ...
#
#                        Subdivision # Fireplaces   Lvls                   Gar  \
# 0                       GEORGETOWN            1  2LEVL                ATTACH
# 1      THE PRESERVE AT EAGLE CREEK            2  1HALF          ATTACH,MULTI
# 2                   NORMANDY FARMS            2  2LEVL                ATTACH
# 3                 TARKINGTON TOWER            0  1LEVL                ATTACH
# 4                 NORTHERN HEIGHTS            1  1LEVL                  NONE
# ...                            ...          ...    ...                   ...
# 16894           SCHLOSS HOME PLACE            0  1LEVL               DETATCH
# 16895                SPEEDWAY CITY            0  1LEVL               DETATCH
# 16896          FALENDERS MEADOWOOD            0  1LEVL               DETATCH
# 16897           SCHLOSS HOME PLACE            0  1LEVL  ATTACH,DETATCH,MULTI
# 16898          FALENDERS MEADOWOOD            0  1LEVL                ATTACH
#
#        # of Garage Spaces  Sq Ft Main Upper Basement Total Sq Ft  DOM  \
# 0                       2             1,600       No       1,600   11
# 1                      4+             4,823      Yes       8,646  150
# 2                       3             3,256      Yes       5,203  163
# 3                       1             1,000       No       1,000  235
# 4                     NaN             1,261      Yes       2,445  171
# ...                   ...               ...      ...         ...  ...
# 16894                   2             1,160      Yes       1,547   17
# 16895                   1             1,116       No       1,116    3
# 16896                   2             1,200      Yes       2,400   10
# 16897                   3               864      Yes       1,728    3
# 16898                   2             1,160      Yes       2,320    2
#
#        List Office MLSID
# 0                 SVTN01
# 1                 WSRL01
# 2                 BHHS01
# 3                 EXPL01
# 4                 CBRL01
# ...                  ...
# 16894             CARP04
# 16895             FARE01
# 16896             CRRD01
# 16897             CESC01
# 16898             TUCK04
#
# [16899 rows x 35 columns]

# %%
johnson_19 = pd.merge(johnson19_a, johnson19a, left_on = 'MLSNumber', right_on = 'BLC # ')

johnson_19
# Out:
#       MLSNumber  NewConstructionYN PropertyType PropertySubType  \
# 0      21666772                NaN  Residential      Single Fam
# 1      21672627                NaN  Residential      Single Fam
# 2      21653501                NaN  Residential      Single Fam
# 3      21666894                NaN  Residential      Single Fam
# 4      21642138                NaN  Residential      Single Fam
# ...         ...                ...          ...             ...
# 1896   21662829                NaN  Residential      Single Fam
# 1897   21658082                NaN  Residential      Single Fam
# 1898   21643862                NaN  Residential      Single Fam
# 1899   21652778                NaN  Residential      Single Fam
# 1900   21670665                NaN  Residential      Single Fam
#
#       StreetNumberAlpha        StreetName      ListAgentFullName  \
# 0                   NaN             Acorn         Jeffrey Paxson
# 1                   NaN            Galaxy          Sheila Bowles
# 2                   NaN  Old Smith Valley           Eddie Rogers
# 3                   NaN          TRESSLAR  Suzanne Roell-Carlson
# 4                   NaN             Hiatt         Penni D. Mayes
# ...                 ...               ...                    ...
# 1896                NaN        Eisenhower          Chase Simpson
# 1897                NaN              Park          Justin Lollar
# 1898                NaN         Cambridge          Justin Lollar
# 1899                NaN               550       Eric Eisenmenger
# 1900                NaN               400           Volly Burton
#
#      CoListAgentFullName  OriginalListPrice  ListPrice  ...       Subdivision  \
# 0      Colleen M. Gordon           109000.0     109000  ...          DEER RUN
# 1                    NaN           125000.0     125000  ...        DEER TRACE
# 2                    NaN            39900.0      39900  ...         GREENWOOD
# 3      Kathleen M. Roell            74900.0      74900  ...    NO SUBDIVISION
# 4                    NaN            87000.0      87000  ...    CHARLES HIATTS
# ...                  ...                ...        ...  ...               ...
# 1896                 NaN           164000.0     164000  ...  PROSSER ADDITION
# 1897                 NaN           174900.0     174900  ...    MEADOW VILLAGE
# 1898                 NaN           189900.0     189900  ...         EDINBURGH
# 1899                 NaN           184900.0     184900  ...    NO SUBDIVISION
# 1900        Woody Burton           229900.0     229900  ...    NO SUBDIVISION
#
#      # Fireplaces   Lvls      Gar  # of Garage Spaces  Sq Ft Main Upper  \
# 0               0  2LEVL   ATTACH                   2             1,450
# 1               0  2LEVL   ATTACH                   1             2,006
# 2               0  1LEVL     NONE                 NaN             2,278
# 3               0  1LEVL  CARPORT                   1               650
# 4               1  1LEVL  DETATCH                   2             1,494
# ...           ...    ...      ...                 ...               ...
# 1896            0  1LEVL    OTHER                 NaN             1,810
# 1897            0  1LEVL   ATTACH                   2             1,850
# 1898            1  2LEVL   ATTACH                   2             1,696
# 1899            0  1LEVL   ATTACH                   2             1,269
# 1900            1  1LEVL  DETATCH                  4+             2,356
#
#      Basement Total Sq Ft DOM  List Office MLSID
# 0          No       1,450  30             JPTM01
# 1          No       2,006  69             LLND01
# 2         Yes       3,417  24             URE 01
# 3          No         650   3             STCR01
# 4          No       1,494  20             TUCK20
# ...       ...         ...  ..                ...
# 1896       No       1,810   5             FCEE01
# 1897       No       1,850  27             FMTR01
# 1898       No       1,696  69             FMTR01
# 1899       No       1,269   4             TRST01
# 1900       No       2,356   1             CARP11
#
# [1901 rows x 35 columns]

# %%
johnson_20 = pd.merge(johnson20_a, johnson20a, left_on = 'MLSNumber', right_on = 'BLC # ')

johnson_20
# Out:
#       MLSNumber  NewConstructionYN PropertyType PropertySubType  \
# 0      21744502                NaN  Residential           Condo
# 1      21743726                NaN  Residential           Condo
# 2      21757165                NaN  Residential      Single Fam
# 3      21754205                NaN  Residential      Single Fam
# 4      21756817                NaN  Residential      Single Fam
# ...         ...                ...          ...             ...
# 2253   21716160                NaN  Residential      Single Fam
# 2254   21739872                NaN  Residential      Single Fam
# 2255   21752069                NaN  Residential      Single Fam
# 2256   21697430                NaN  Residential      Single Fam
# 2257   21718971                NaN  Residential      Single Fam
#
#       StreetNumberAlpha      StreetName  ListAgentFullName  \
# 0                   NaN     Easy Unit B     Valerie Vaughn
# 1                   NaN     Easy Unit A     Valerie Vaughn
# 2                   NaN       Clubhouse           Ri Khuma
# 3                   NaN            Mesa      Marie Edwards
# 4                   NaN          Napier        Fred Nelson
# ...                 ...             ...                ...
# 2253                NaN      Main Cross  Cindy L. Patchett
# 2254                NaN   US Highway 31     Jake R. Stiles
# 2255                NaN         Orchard   Justin A. Lollar
# 2256                NaN  State Road 252   Justin A. Lollar
# 2257                NaN       Cambridge       Matthew Toth
#
#      CoListAgentFullName  OriginalListPrice  ListPrice  ...  \
# 0                    NaN           255000.0     255000  ...
# 1                    NaN           265000.0     259000  ...
# 2                    NaN           269900.0     269900  ...
# 3                    NaN           293695.0     293695  ...
# 4                    NaN           297610.0     297610  ...
# ...                  ...                ...        ...  ...
# 2253                 NaN           159900.0     159900  ...
# 2254    Jamie E. Spitler           169900.0     169900  ...
# 2255                 NaN           189900.0     189900  ...
# 2256                 NaN           209900.0     209900  ...
# 2257                 NaN           215000.0     215000  ...
#
#             Subdivision # Fireplaces   Lvls      Gar  # of Garage Spaces  \
# 0        NO SUBDIVISION            1  1LEVL   ATTACH                   2
# 1        NO SUBDIVISION            1  1LEVL   ATTACH                   2
# 2              CAREFREE            1  1LEVL   ATTACH                   2
# 3        Highland Knoll            0  1LEVL   ATTACH                   2
# 4           MORNINGSIDE            0  1LEVL   ATTACH                   2
# ...                 ...          ...    ...      ...                 ...
# 2253              KINGS            1  2LEVL  DETATCH                   2
# 2254     NO SUBDIVISION            0  1LEVL  DETATCH                   2
# 2255       ORCHARD PARK            0  1LEVL   ATTACH                   2
# 2256          EDINBURGH            1  1LEVL   ATTACH                   2
# 2257  OLD TOWNE ESTATES            0  2LEVL   ATTACH                   3
#
#       Sq Ft Main Upper Basement Total Sq Ft  DOM  List Office MLSID
# 0                1,541       No       1,541  110             IHRC01
# 1                1,578       No       1,578  115             IHRC01
# 2                1,958       No       1,958   43             FTRE01
# 3                1,583       No       1,583   67             HMSR01
# 4                1,582       No       1,582   45             CESC02
# ...                ...      ...         ...  ...                ...
# 2253             2,382      Yes       2,911    3             RREP01
# 2254               990       No         990    1             STIL01
# 2255             1,328       No       1,328    1             FMTR01
# 2256               986      Yes       1,972   35             FMTR01
# 2257             2,084       No       2,084    2             FMTR01
#
# [2258 rows x 35 columns]

# %%
johnson_20.columns
# Out:
# Index(['MLSNumber', 'NewConstructionYN', 'PropertyType', 'PropertySubType',
#        'StreetNumberAlpha', 'StreetName', 'ListAgentFullName',
#        'CoListAgentFullName', 'OriginalListPrice', 'ListPrice',
#        'ListingContractDate', 'ExpirationDate', 'SellingOfficeName',
#        'SellingAgentFullName ', 'Unnamed: 0', 'BLC # ', 'St', 'P Type',
#        'Address', 'Area', 'List/MoRnt $', 'Beds Total', 'Baths Full',
#        'Baths Half', 'Sch D', 'Subdivision', '# Fireplaces', 'Lvls', 'Gar',
#        '# of Garage Spaces', 'Sq Ft Main Upper', 'Basement', 'Total Sq Ft',
#        'DOM', 'List Office MLSID'],
#       dtype='object')

# %%
ListPrice = johnson_20["ListPrice"].mean()
ListPrice
# Out:
# 266132.2373782108

# %%
ListPric1e = marion_20["ListPrice"].mean()
ListPric1e
# Out:
# 222403.0682288893
